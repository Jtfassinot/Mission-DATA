# %%
import pandas  as pd

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("hemil26/crime-in-los-angeles")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /Users/julien-thomasfassinot/.cache/kagglehub/datasets/hemil26/crime-in-los-angeles/versions/8

# %%
df = pd.read_csv("/Users/julien-thomasfassinot/.cache/kagglehub/datasets/hemil26/crime-in-los-angeles/versions/8/crime_in_la.csv")

# %%
df.head()
# Out:
#        DR_NO    DATE OCC TIME OCC  AREA  AREA NAME  Rpt Dist No  Crm Cd  \
# 0  190326475  01/03/2020    21:30     7   Wilshire          784     510
# 1  200106753  08/02/2020    18:00     1    Central          182     330
# 2  200320258  04/11/2020    17:00     3  Southwest          356     480
# 3  200907217  10/03/2020    20:37     9   Van Nuys          964     343
# 4  220614831  17/08/2020    12:00     6  Hollywood          666     354
#
#                                 Crm Cd Desc              Mocodes  Vict Age  \
# 0                          VEHICLE - STOLEN                    0         0
# 1                     BURGLARY FROM VEHICLE       1822 1402 0344        47
# 2                             BIKE - STOLEN            0344 1251        19
# 3  SHOPLIFTING-GRAND THEFT ($950.01 & OVER)            0325 1501        19
# 4                         THEFT OF IDENTITY  1822 1501 0930 2004        28
#
#   Vict Sex Vict Descent                                   Premis Desc  \
# ...

# %%
import missingno as msno
import matplotlib.pyplot as plt

# Visualisation des valeurs manquantes
msno.bar(df)
plt.show()

# %%
import numpy as np
import seaborn as sns


# Sélectionner uniquement les colonnes numériques
df_numeric = df.select_dtypes(include=[np.number])

# Calculer la matrice de corrélation
corr = df_numeric.corr()

# Masquer la moitié supérieure
mask = np.triu(np.ones_like(corr, dtype=bool))

# Configurer la figure matplotlib
plt.figure(figsize=(10, 8))
sns.heatmap(corr, mask=mask, annot=True, cmap="coolwarm", fmt=".2f", linewidths=0.5)

# Afficher la heatmap
plt.title("Demi-Matrice de Corrélation")
plt.show()

# %%
df.describe
# Out:
# <bound method NDFrame.describe of             DR_NO    DATE OCC TIME OCC  AREA   AREA NAME  Rpt Dist No  Crm Cd  \
# 0       190326475  01/03/2020    21:30     7    Wilshire          784     510
# 1       200106753  08/02/2020    18:00     1     Central          182     330
# 2       200320258  04/11/2020    17:00     3   Southwest          356     480
# 3       200907217  10/03/2020    20:37     9    Van Nuys          964     343
# 4       220614831  17/08/2020    12:00     6   Hollywood          666     354
# ...           ...         ...      ...   ...         ...          ...     ...
# 963001  242106032  17/02/2024    23:30    21     Topanga         2103     420
# 963002  242004546  16/01/2024    15:10    20     Olympic         2013     624
# 963003  240104953  15/01/2024    01:00     1     Central          101     745
# 963004  241711348  19/07/2024    07:57    17  Devonshire         1751     888
# 963005  240309674  24/04/2024    15:00     3   Southwest          358     230
#
# ...

# %%
df['Vict Sex'].value_counts()
# Out:
# Vict Sex
# M    391192
# F    348487
# X    223217
# H       109
# -         1
# Name: count, dtype: int64

# %%
df_female = df[df['Vict Sex'] == "F"]

# %%
df.columns
# Out:
# Index(['DR_NO', 'DATE OCC', 'TIME OCC', 'AREA', 'AREA NAME', 'Rpt Dist No',
#        'Crm Cd', 'Crm Cd Desc', 'Mocodes', 'Vict Age', 'Vict Sex',
#        'Vict Descent', 'Premis Desc', 'Weapon Used Cd', 'Weapon Desc',
#        'Status', 'Status Desc', 'LOCATION', 'LAT', 'LON'],
#       dtype='object')

# %%
df.drop(columns=['AREA',
       'Crm Cd', 'Weapon Used Cd','Status'], inplace=True)

# %%
df.columns
# Out:
# Index(['DR_NO', 'DATE OCC', 'TIME OCC', 'AREA NAME', 'Rpt Dist No',
#        'Crm Cd Desc', 'Mocodes', 'Vict Age', 'Vict Sex', 'Vict Descent',
#        'Premis Desc', 'Weapon Desc', 'Status Desc', 'LOCATION', 'LAT', 'LON'],
#       dtype='object')

# %%
df_female.to_csv('female.csv', index=False)
